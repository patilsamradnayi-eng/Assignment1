# %% [markdown]
# <a href="https://colab.research.google.com/github/patilsamradnayi-eng/Assignment1/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str1 = "Hello"

length = len(str1)
print("Length of string is:", length)

str1 = "Python"

if len(str1) < 2:
    print("Empty String")
else:
    new_str = str1[:2] + str1[-2:]
    print("New string:", new_str)

str1 = "Hello"
str2 = "World"

result = str1 + str2
print("Concatenated string:", result)
# Out:
# Length of string is: 5
# New string: Pyon
# Concatenated string: HelloWorld
